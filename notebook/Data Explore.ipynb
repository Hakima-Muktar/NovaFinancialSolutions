# %%
import pandas as pd
import numpy as  np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import sys

# %% [markdown]
# #Load News

# %%
# Get the absolute path to the project root
notebook_dir = os.path.dirname(os.path.abspath(''))
project_root = os.path.abspath(os.path.join(notebook_dir, '..'))
sys.path.append(project_root)  # Add the project root to the path

# %%
import os

print(os.listdir(project_root))
# Out:
# ['cd-practice', 'coop', 'customer-experience-analytics-fintech-apps', 'Detecting-Spam-Email', 'ethio_medical_telegram_analytics', 'finance', 'predicting-price-moves-with-news', 'sample', 'solar-challenge-week-0', 'Stock-Price-Prediction-TensorFlow', 'stock_market', 'Test1', 'tre1', 'week1']

# %%
# Load the data using absolute path
data_file = r"C:/Users/User/Desktop/KAIM/project/predicting-price-moves-with-news/data/news/raw_analyst_ratings.csv"
news_data = pd.read_csv(data_file)
print(f"Successfully loaded data: {news_data.shape}")
# Out:
# Successfully loaded data: (1407328, 6)

# %%
# Basic plot setup
plt.figure(figsize=(10, 6))
sns.set(style="whitegrid")

# Try to load data
try:
    # Load raw data
    news_data = pd.read_csv(data_file)
    print(f"Successfully loaded data: {news_data.shape}")
    
    # Display first few rows
    print("\nFirst few rows:")
    print(news_data.head())
    
    # Get column names
    print("\nColumns:")
    print(news_data.columns.tolist())
    
except Exception as e:
    print(f"Error loading data: {e}")
# Out:
# Successfully loaded data: (1407328, 6)
#
# First few rows:
#    Unnamed: 0                                           headline  \
# 0           0            Stocks That Hit 52-Week Highs On Friday
# 1           1         Stocks That Hit 52-Week Highs On Wednesday
# 2           2                      71 Biggest Movers From Friday
# 3           3       46 Stocks Moving In Friday's Mid-Day Session
# 4           4  B of A Securities Maintains Neutral on Agilent...
#
#                                                  url          publisher  \
# 0  https://www.benzinga.com/news/20/06/16190091/s...  Benzinga Insights
# 1  https://www.benzinga.com/news/20/06/16170189/s...  Benzinga Insights
# 2  https://www.benzinga.com/news/20/05/16103463/7...         Lisa Levin
# 3  https://www.benzinga.com/news/20/05/16095921/4...         Lisa Levin
# 4  https://www.benzinga.com/news/20/05/16095304/b...         Vick Meyer
#
#                         date stock
# 0  2020-06-05 10:30:54-04:00     A
# ...

# %%
# statistical summary
print(data_file.describe())
# Out:
#          Unnamed: 0  headline_length
# count  1.407328e+06     1.407328e+06
# mean   7.072454e+05     7.312051e+01
# std    4.081009e+05     4.073531e+01
# min    0.000000e+00     3.000000e+00
# 25%    3.538128e+05     4.700000e+01
# 50%    7.072395e+05     6.400000e+01
# 75%    1.060710e+06     8.700000e+01
# max    1.413848e+06     5.120000e+02

# %%
# missing values
print(data_file.isnull().sum())
# Out:
# Unnamed: 0         0
# headline           0
# url                0
# publisher          0
# date               0
# stock              0
# headline_length    0
# dtype: int64

# %%
# duplicated values
print(data_file.duplicated().sum())
# Out:
# 0

# %%
# count length
import pandas as pd
data_file = pd.read_csv(data_file)
data_file['headline_length'] = data_file['headline'].astype(str).apply(len)

# %%
# time series plot of stock over date
plt.figure(figsize=(10,6))
df["stock"].astype(str).str.len().hist(bins=20)
plt.title("time series plot of stock over date")
# Setting the X and Y labels
plt.xlabel('stock')
plt.ylabel('date')
# Adding the legends
plt.show()

# %%
plt.figure(figsize=(8,4))
df["headline"].astype(str).str.len().hist(bins=30)
plt.title("Headline Length Distribution")
plt.xlabel("Characters")
plt.ylabel("Count")
plt.show()

# %%
# visulize distribution of target publisher variable
plt.figure(figsize=(10,6))
plt.bar(df['publisher'].value_counts().head(10).index, df['publisher'].value_counts().head(10).values)
plt.title("Top 10 Publishers")
plt.xlabel("Publisher")
plt.ylabel("Articles")
plt.xticks(rotation=45)
plt.show()

# %%
# visulize distribution of target variable
plt.figure(figsize=(10,6))
df["date"].astype(str).str.len().hist(bins=30)
plt.title("Distribution of headlines by date")
plt.xlabel('date')
plt.ylabel('headlines')
plt.show()
