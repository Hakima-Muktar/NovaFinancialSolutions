# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt    
import quantstats as qs    
from src.news import load_news_csv, headline_length_stats, articles_per_publisher

# %% [markdown]
# #Load News

# %%
news_path = "data/news/raw_analyst_ratings.csv" 
df = load_news_csv(news_path)
df.head()
# Out:
# Running cells with 'venv (Python 3.12.0)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/User/Desktop/project/NovaFinancialSolutions/venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %% [markdown]
# # Headline Length Statistics

# %%
stats = headline_length_stats(df)
print("Headline Length Statistics:")
print(stats)
plt.figure(figsize=(8,4))
df["headline"].astype(str).str.len().hist(bins=40)
plt.title("Headline Length Distribution")
plt.xlabel("Characters")
plt.ylabel("Count")
plt.show()
# Out:
# Running cells with 'venv (Python 3.12.0)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/User/Desktop/project/NovaFinancialSolutions/venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %% [markdown]
# # Count Articles Per Publisher

# %%
plt.figure(figsize=(10,5))
plt.title("Top 10 Publishers")
plt.xlabel("Publisher")
plt.ylabel("Articles")
plt.xticks(rotation=45)
plt.show()
# Out:
# Running cells with 'venv (Python 3.12.0)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/User/Desktop/project/NovaFinancialSolutions/venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'
